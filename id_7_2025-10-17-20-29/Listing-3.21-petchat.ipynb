# %%
"""PyCharm (No LangChain) — OpenRouter chat loop (replace Azure, our compact style)"""

# ============================================================================
# IMPORTS
# ============================================================================
import os
from dotenv import load_dotenv
from openai import OpenAI

# ============================================================================
# ENVIRONMENT SETUP (fail-fast)
# ============================================================================
load_dotenv()
OPENROUTER_API_KEY  = os.getenv("OPENROUTER_API_KEY")
OPENROUTER_BASE_URL = os.getenv("OPENROUTER_BASE_URL")
if not OPENROUTER_API_KEY:  raise RuntimeError("Missing OPENROUTER_API_KEY in .env")
if not OPENROUTER_BASE_URL: raise RuntimeError("Missing OPENROUTER_BASE_URL in .env")

# ============================================================================
# MAIN
# ============================================================================
def main():
    client = OpenAI(api_key=OPENROUTER_API_KEY, base_url=OPENROUTER_BASE_URL)

    conversation = [
        {"role": "system", "content": "You are a helpful AI assistant and happy to talk about pets and salons."}
    ]

    print("Chat started (Ctrl+C to exit).")
    try:
        while True:
            user_input = input("> ").strip()
            if not user_input:
                continue
            conversation.append({"role": "user", "content": user_input})

            resp = client.chat.completions.create(
                model="openai/gpt-4o",
                temperature=0.7,
                messages=conversation,
                max_tokens=800,
            )
            reply = resp.choices[0].message.content.strip()
            conversation.append({"role": "assistant", "content": reply})
            print("\n" + reply + "\n")
    except KeyboardInterrupt:
        print("\nBye!")

# ============================================================================
# SCRIPT EXECUTION
# ============================================================================
if __name__ == "__main__":
    main()
# Out:
# Chat started (Ctrl+C to exit).
#
# Hello! How can I assist you today? Are you interested in discussing pets or maybe something about salons?
#
#
# Hello! It seems like you're referring to "Byte." Could you clarify what you mean? Are you talking about a digital topic, a pet, or perhaps something else? Let me know how I can help!
