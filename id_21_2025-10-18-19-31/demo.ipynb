# %%
# Check Python runtime information
import sys
import platform

print("Python Runtime Information:")
print("=" * 40)
print(f"Python Version: {sys.version}")
print(f"Python Executable: {sys.executable}")
print(f"Platform: {platform.platform()}")
print(f"Architecture: {platform.architecture()}")
print(f"Machine: {platform.machine()}")
print(f"Processor: {platform.processor()}")
print("=" * 40)
# Out:
# Python Runtime Information:
# ========================================
# Python Version: 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]
# Python Executable: D:\AI-Engineer\16_AI Assistant and Agentic AI\03_AI Assistant and Agentic\2025-10-29-18-46\langchain1\.venv\Scripts\python.exe
# Platform: Windows-11-10.0.26200-SP0
# Architecture: ('64bit', 'WindowsPE')
# Machine: AMD64
# Processor: Intel64 Family 6 Model 186 Stepping 2, GenuineIntel
# ========================================

# %%
pip install tiktoken
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: tiktoken in d:\ai-engineer\ai-api-call-py-udemy-1\test-powershell-script-for-initialization-project-v2\langchain-course\.venv\lib\site-packages (0.12.0)
# Requirement already satisfied: regex>=2022.1.18 in d:\ai-engineer\ai-api-call-py-udemy-1\test-powershell-script-for-initialization-project-v2\langchain-course\.venv\lib\site-packages (from tiktoken) (2025.9.18)
# Requirement already satisfied: requests>=2.26.0 in d:\ai-engineer\ai-api-call-py-udemy-1\test-powershell-script-for-initialization-project-v2\langchain-course\.venv\lib\site-packages (from tiktoken) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\ai-engineer\ai-api-call-py-udemy-1\test-powershell-script-for-initialization-project-v2\langchain-course\.venv\lib\site-packages (from requests>=2.26.0->tiktoken) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in d:\ai-engineer\ai-api-call-py-udemy-1\test-powershell-script-for-initialization-project-v2\langchain-course\.venv\lib\site-packages (from requests>=2.26.0->tiktoken) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\ai-engineer\ai-api-call-py-udemy-1\test-powershell-script-for-initialization-project-v2\langchain-course\.venv\lib\site-packages (from requests>=2.26.0->tiktoken) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\ai-engineer\ai-api-call-py-udemy-1\test-powershell-script-for-initialization-project-v2\langchain-course\.venv\lib\site-packages (from requests>=2.26.0->tiktoken) (2025.10.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
